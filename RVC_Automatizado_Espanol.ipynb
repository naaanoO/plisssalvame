# %% [markdown]
# # RVC Automático en Español
# Este notebook entrena tu voz y reemplaza la voz original de una canción automáticamente.

# %% [markdown]
# ## Paso 1: Archivos cargados

# %%
# Estos archivos deben subirse manualmente si se abre en Colab directamente
from google.colab import files
print('Sube tu archivo de voz (gpt.m4a)')
voice = files.upload()
print('Sube tu canción original (su culazo.mp3)')
song = files.upload()
# Out:
# Sube tu archivo de voz (gpt.m4a)
#      <input type="file" id="files-b644f161-b047-4a77-befb-0b8eb62a8f62" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b644f161-b047-4a77-befb-0b8eb62a8f62">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %% [markdown]
# ## Paso 2: Instalar RVC y dependencias

# %%
# !git clone https://github.com/RVC-Project/Retrieval-based-Voice-Conversion-WebUI.git
# %cd Retrieval-based-Voice-Conversion-WebUI
# !pip install -r requirements.txt
# Out:
# Cloning into 'Retrieval-based-Voice-Conversion-WebUI'...
# remote: Enumerating objects: 4593, done.
# remote: Total 4593 (delta 0), reused 0 (delta 0), pack-reused 4593 (from 1)
# Receiving objects: 100% (4593/4593), 14.33 MiB | 20.64 MiB/s, done.
# Resolving deltas: 100% (2883/2883), done.
# /content/Retrieval-based-Voice-Conversion-WebUI
# Ignoring onnxruntime: markers 'sys_platform == "darwin"' don't match your environment
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 23.2 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# ...

# %% [markdown]
# ## Paso 3: Convertir la voz automáticamente

# %%
# Aquí se asumiría un proceso automatizado con comandos personalizados
# Pero normalmente se usa la interfaz web de RVC
# Abre la interfaz con el siguiente comando:
# !python3 infer-web.py --pycmd python --port 7865
# Out:
# python3: can't open file '/content/drive/MyDrive/Colab Notebooks/infer-web.py': [Errno 2] No such file or directory

# %%
# !git clone https://github.com/usuario/repositorio.git
# Out:
# Cloning into 'repositorio'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
git remote add origin https://github.com/naaanoO/plisssalvame.git
# Out:
#   File "<ipython-input-26-e8cf48ca4304>", line 1
#     git remote add origin https://github.com/naaanoO/plisssalvame.git
#         ^
# SyntaxError: invalid syntax
